# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
print('Ended')
# Out:
# Initialized
# Average loss at step 0: 8.290689
# Nearest to by: imagining, nationalized, genealogies, peritoneum, adjustments, toland, docile, catherine,
# Nearest to eight: jakobson, be, comic, blubber, battle, aerobatic, unscathed, dumb,
# Nearest to it: spit, resented, hindustani, vantaa, wtoo, multidisciplinary, chiao, demographics,
# Nearest to zero: overly, amundsen, paterson, rebus, ferocity, argento, saxophonist, effectively,
# Nearest to use: gere, doolittle, tsinghua, grunwald, tire, symbiosis, property, offending,
# Nearest to known: gev, spotting, overthrow, hrothgar, frantz, shelton, armored, aragorn,
# Nearest to all: busing, interviewed, plata, carolyn, acacias, vines, gendered, luca,
# Nearest to called: disbandment, psychedelics, thunderball, kapitan, gleaned, gu, silicate, sel,
# Nearest to from: rash, clumsy, stump, principia, beit, supposition, fielded, principle,
# Nearest to when: oic, sind, orion, maria, disparaging, prolonging, chanced, bid,
# Nearest to system: intercession, expensive, categorised, farmland, bonded, cognition, wenzel, lever,
# Nearest to d: gif, manic, littlefield, subverting, roaring, bees, susa, poets,
# Nearest to there: paths, mould, robbery, crests, attractive, fp, rover, euphoric,
# Nearest to at: gotland, fibres, buoyancy, luang, twinned, bother, returns, doe,
# Nearest to will: rush, capt, posthumous, ale, paddy, exits, yockey, rocketry,
# Nearest to first: ayyubid, cav, mandarin, pitting, taliesin, mysteries, damage, sexton,
# Average loss at step 2000: 4.371964
# Average loss at step 4000: 3.870084
# Average loss at step 6000: 3.788042
# Average loss at step 8000: 3.687914
# Average loss at step 10000: 3.615903
# Nearest to by: was, as, with, be, been, after, distinguishing, when,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to it: he, this, there, they, which, but, that, she,
# Nearest to zero: nine, five, six, seven, eight, three, four, two,
# Nearest to use: symbiosis, swapping, resurrect, courtesy, tsinghua, interlinked, rriais, brosnan,
# Nearest to known: used, spotting, subversion, willis, dont, regarded, a, yelling,
# Nearest to all: vines, busing, these, teh, traction, receding, pilgrim, nurturing,
# Nearest to called: psychedelics, disbandment, matti, handlebar, barre, sel, wrestler, demands,
# Nearest to from: into, advertisement, in, roebuck, boat, mediated, wide, clumsy,
# Nearest to when: oic, disparaging, by, reciprocal, emit, sind, firmware, modesty,
# Nearest to system: chambers, chicagoland, biologically, intercession, gigahertz, cognition, folksong, lever,
# Nearest to d: and, b, parcels, leveling, littlefield, adjective, constitutions, capybaras,
# Nearest to there: paths, it, he, they, fp, rover, projects, vociferous,
# Nearest to at: in, forerunners, aleksei, on, yakko, caligula, bottleneck, under,
# Nearest to will: would, can, rush, doll, macaroni, pannonia, vukovar, ale,
# Nearest to first: pitting, deirdre, yamaguchi, displeased, rims, tamias, regional, mandatory,
# Average loss at step 12000: 3.608585
# Average loss at step 14000: 3.572655
# Average loss at step 16000: 3.404809
# Average loss at step 18000: 3.453114
# Average loss at step 20000: 3.545340
# Nearest to by: with, be, for, when, were, have, was, begining,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to it: he, this, there, they, which, she, we, not,
# Nearest to zero: six, five, seven, eight, nine, four, three, two,
# Nearest to use: swapping, rriais, symbiosis, courtesy, resurrect, hamlet, sepia, doolittle,
# Nearest to known: used, regarded, such, far, factories, seen, spotting, sequenced,
# Nearest to all: these, some, many, vines, pilgrim, portion, those, astigmatism,
# Nearest to called: psychedelics, tippit, atum, saville, systemic, barre, probably, haka,
# Nearest to from: into, in, under, at, amd, mediated, through, scare,
# Nearest to when: if, was, after, by, unhelpful, disparaging, though, although,
# Nearest to system: chambers, gigahertz, chicagoland, cometary, submachine, layoffs, jannaeus, coffers,
# Nearest to d: b, adjective, parcels, capybaras, constitutions, leveling, gatwick, teammate,
# Nearest to there: it, they, he, paths, vociferous, which, substrates, but,
# Nearest to at: in, under, yakko, from, on, is, ps, recollection,
# Nearest to will: would, can, may, should, could, to, must, pannonia,
# Nearest to first: tradeoffs, trackball, pitting, hicks, deirdre, yamaguchi, xinhua, tenures,
# Average loss at step 22000: 3.498510
# Average loss at step 24000: 3.491811
# Average loss at step 26000: 3.479192
# Average loss at step 28000: 3.479450
# Average loss at step 30000: 3.503114
# Nearest to by: overtime, from, begining, juli, in, was, cursor, were,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to it: he, there, this, they, she, which, also, not,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to use: rriais, swapping, symbiosis, brosnan, resurrect, courtesy, hamlet, interlinked,
# Nearest to known: regarded, used, such, described, referred, seen, far, well,
# Nearest to all: these, some, many, those, vines, photographs, control, teh,
# Nearest to called: barre, tippit, saville, psychedelics, atum, probably, complicating, haka,
# Nearest to from: into, under, in, of, and, on, through, against,
# Nearest to when: if, after, though, during, where, was, but, before,
# Nearest to system: systems, jannaeus, chicagoland, cerberus, nta, biologically, games, gigahertz,
# Nearest to d: b, adjective, parcels, acf, mic, teammate, calves, l,
# Nearest to there: they, it, he, paths, which, we, substrates, often,
# Nearest to at: in, under, aleksei, during, motto, on, yakko, when,
# Nearest to will: would, can, may, could, should, must, might, to,
# Nearest to first: second, next, tradeoffs, xinhua, yamaguchi, trackball, allman, hicks,
# Average loss at step 32000: 3.504302
# Average loss at step 34000: 3.493052
# Average loss at step 36000: 3.457052
# Average loss at step 38000: 3.303432
# Average loss at step 40000: 3.430245
# Nearest to by: when, matilda, grave, schlesinger, with, cerberus, as, be,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to it: he, there, they, she, this, which, not, still,
# Nearest to zero: seven, five, nine, eight, six, four, three, two,
# Nearest to use: swapping, resurrect, ebay, molar, allow, symbiosis, select, rriais,
# Nearest to known: regarded, used, such, described, possible, seen, thurston, well,
# Nearest to all: these, control, each, both, several, many, various, teh,
# Nearest to called: atum, barre, psychedelics, considered, saville, cristae, probably, competent,
# Nearest to from: into, in, under, through, rash, parsers, between, of,
# Nearest to when: if, after, before, though, where, while, by, gave,
# Nearest to system: systems, jannaeus, doric, nta, proprietary, hazing, cometary, folksong,
# Nearest to d: b, adjective, parcels, rammed, crewmen, ores, gif, recovering,
# Nearest to there: they, it, he, which, often, usually, these, we,
# Nearest to at: during, on, frazer, yakko, under, in, notified, celibate,
# Nearest to will: would, can, may, could, should, must, might, to,
# Nearest to first: second, next, tradeoffs, last, hicks, emacs, xinhua, original,
# Average loss at step 42000: 3.441533
# Average loss at step 44000: 3.448901
# Average loss at step 46000: 3.455329
# Average loss at step 48000: 3.355480
# Average loss at step 50000: 3.385867
# Nearest to by: under, matilda, through, was, digestive, while, begining, thereupon,
# Nearest to eight: seven, six, nine, four, five, three, zero, two,
# Nearest to it: he, there, she, they, this, still, resented, also,
# Nearest to zero: eight, seven, five, four, nine, six, three, two,
# Nearest to use: most, lack, interlinked, study, select, swapping, value, removal,
# Nearest to known: used, regarded, possible, described, such, seen, well, diverse,
# Nearest to all: control, these, each, both, some, various, shielded, any,
# Nearest to called: atum, barre, sled, competent, gleaned, nrc, psychedelics, dovich,
# Nearest to from: into, under, in, parsers, after, through, caucasus, extraction,
# Nearest to when: if, after, while, before, though, where, although, during,
# Nearest to system: systems, jannaeus, proprietary, statehood, koalas, fibrosis, whitlam, doric,
# Nearest to d: b, c, rammed, m, l, adjective, crewmen, bhp,
# Nearest to there: they, it, he, paths, we, she, who, generally,
# Nearest to at: notified, during, on, yakko, parlor, acetone, speckled, under,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to first: second, next, last, original, xinhua, same, cynicism, propellant,
# Average loss at step 52000: 3.438561
# Average loss at step 54000: 3.430025
# Average loss at step 56000: 3.440156
# Average loss at step 58000: 3.391635
# Average loss at step 60000: 3.398689
# Nearest to by: through, begining, matilda, canines, digestive, westerner, when, from,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to it: he, there, this, she, which, they, then, still,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to use: most, treatment, swapping, select, interlinked, purpose, ebay, allow,
# Nearest to known: regarded, used, possible, such, described, seen, diverse, referred,
# Nearest to all: both, each, these, various, many, some, those, any,
# Nearest to called: atum, used, sled, referred, considered, injera, investigator, dovich,
# Nearest to from: through, into, under, in, after, roebuck, parsers, across,
# Nearest to when: if, before, after, although, while, where, though, because,
# Nearest to system: systems, jannaeus, proprietary, complete, whitlam, scene, oligocene, hazing,
# Nearest to d: b, c, m, l, rammed, parcels, recovering, gif,
# Nearest to there: they, it, he, she, we, this, now, which,
# Nearest to at: in, parlor, under, notified, yakko, legitimize, aleksei, during,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to first: second, next, last, same, xinhua, original, propellant, third,
# Average loss at step 62000: 3.241393
# Average loss at step 64000: 3.253976
# Average loss at step 66000: 3.401825
# Average loss at step 68000: 3.396157
# Average loss at step 70000: 3.361541
# Nearest to by: digestive, through, bullpen, was, be, cerberus, begining, westerner,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to it: he, there, this, she, they, still, which, itself,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to use: treatment, most, allow, study, support, lack, cause, interlinked,
# Nearest to known: used, regarded, described, possible, such, seen, referred, well,
# Nearest to all: various, many, some, these, both, westermann, any, each,
# Nearest to called: used, sled, postulate, atum, referred, jmp, owls, investigator,
# Nearest to from: through, into, under, in, across, roebuck, parsers, between,
# Nearest to when: if, before, while, though, after, where, however, because,
# Nearest to system: systems, palette, proprietary, whitlam, jannaeus, scene, hazing, cod,
# Nearest to d: b, parcels, rammed, recovering, l, gif, bhp, ores,
# Nearest to there: they, it, he, we, she, now, generally, still,
# Nearest to at: in, notified, yakko, caligula, during, acetone, under, underage,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to first: second, next, last, same, xinhua, original, third, propellant,
# Average loss at step 72000: 3.379227
# Average loss at step 74000: 3.347700
# Average loss at step 76000: 3.312813
# Average loss at step 78000: 3.352649
# Average loss at step 80000: 3.377552
# Nearest to by: juli, begining, under, through, thereupon, bullpen, reston, digestive,
# Nearest to eight: six, nine, seven, five, four, three, zero, one,
# Nearest to it: he, she, there, this, they, itself, not, we,
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to use: treatment, lack, study, support, cause, because, allow, swapping,
# Nearest to known: regarded, used, described, seen, referred, possible, such, depicted,
# Nearest to all: both, various, many, some, these, several, every, westermann,
# Nearest to called: used, atum, referred, considered, sled, known, investigator, gleaned,
# Nearest to from: through, into, under, rash, thirties, parsers, within, after,
# Nearest to when: if, though, before, after, while, during, where, although,
# Nearest to system: systems, proprietary, jannaeus, fibrosis, banish, whitlam, polyphony, forensic,
# Nearest to d: b, recovering, l, gif, parcels, iso, ores, rodrigues,
# Nearest to there: it, they, he, she, we, who, often, now,
# Nearest to at: in, under, acetone, during, parlor, notified, on, yakko,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to first: second, next, last, same, third, original, xinhua, varuna,
# Average loss at step 82000: 3.404410
# Average loss at step 84000: 3.409848
# Average loss at step 86000: 3.390619
# Average loss at step 88000: 3.357087
# Average loss at step 90000: 3.364473
# Nearest to by: through, digestive, with, begining, bullpen, under, juli, when,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to it: he, she, there, this, they, itself, never, actually,
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Nearest to use: treatment, study, support, allow, lack, provide, most, purpurea,
# Nearest to known: regarded, used, described, such, seen, possible, referred, called,
# Nearest to all: many, various, some, both, several, each, bacteriology, westermann,
# Nearest to called: used, considered, referred, known, atum, systemic, lydian, gleaned,
# Nearest to from: through, into, parsers, before, across, during, heritability, between,
# Nearest to when: if, while, before, though, after, where, until, because,
# Nearest to system: systems, device, cod, proprietary, prototypes, jannaeus, problem, scene,
# Nearest to d: b, apr, iso, inscribed, parcels, overtook, gif, recovering,
# Nearest to there: they, it, he, she, we, now, still, often,
# Nearest to at: during, under, on, in, near, lez, hail, onto,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to first: second, last, next, original, same, xinhua, third, following,
# Average loss at step 92000: 3.401161
# Average loss at step 94000: 3.253739
# Average loss at step 96000: 3.360240
# Average loss at step 98000: 3.244471
# Average loss at step 100000: 3.359024
# Nearest to by: juli, reston, through, matilda, been, jacqueline, bullpen, begining,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to it: he, she, this, there, they, never, itself, actually,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to use: treatment, study, support, allow, cause, lack, purpurea, appreciation,
# Nearest to known: regarded, used, possible, described, such, seen, called, defined,
# Nearest to all: many, various, these, every, some, both, several, any,
# Nearest to called: known, referred, used, atum, named, investigator, considered, systemic,
# Nearest to from: through, into, in, during, across, before, parsers, at,
# Nearest to when: if, while, though, although, where, before, after, because,
# Nearest to system: systems, device, proprietary, problem, polyphony, jannaeus, sway, software,
# Nearest to d: b, gif, iso, c, overtook, august, ores, monte,
# Nearest to there: they, it, he, we, now, she, still, often,
# Nearest to at: during, in, on, ec, under, underage, with, acetone,
# Nearest to will: would, could, must, can, should, may, might, cannot,
# Nearest to first: next, second, last, same, third, fourth, original, xinhua,
# Ended

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, tf.reduce_sum(embeds, 1),
                              num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
print('Ended')
# Out:
# Initialized
# Average loss at step 0: 7.038775
# Nearest to were: cleaned, visibly, centriole, constructivism, volkov, thrilling, nagpur, clerical,
# Nearest to b: sul, hitting, sunsets, cocoon, udp, park, prefer, abdomen,
# Nearest to use: until, hissing, undifferentiated, rosalind, declarative, recurrence, unhappy, fujiko,
# Nearest to states: spider, agm, categorical, rotary, johann, shir, era, nonviolent,
# Nearest to american: causality, gskola, stolen, lately, abortion, vientiane, festivals, registries,
# Nearest to six: solace, gaza, cassini, vulgar, bloodshed, bender, ops, pursues,
# Nearest to with: gander, devry, novelists, sena, mumps, rpg, malayan, transmitting,
# Nearest to four: me, iran, birthrate, extension, strikes, witt, economics, timeout,
# Nearest to on: resurrection, montane, krona, manatus, transcripts, scipione, synthesis, workout,
# Nearest to they: paperbacks, selecting, milestone, hellenic, chips, ppg, residue, coronations,
# Nearest to used: usr, plo, monocotyledons, kia, utilise, walking, eskimo, strictly,
# Nearest to so: rgen, joss, mouthpiece, hashshashin, holomorphic, harmonising, icq, expressions,
# Nearest to but: retainers, ionia, rables, bigcup, journeying, stow, augusto, suri,
# Nearest to or: fledged, kept, condensation, shmuel, supp, paphos, stefano, mediate,
# Nearest to after: wei, varna, radioisotopes, uncountable, seen, admixtures, multilateral, depends,
# Nearest to are: biblical, peninsular, memetics, besson, sanhedrin, varied, arabians, faunas,
# Average loss at step 2000: 4.608830
# Average loss at step 4000: 3.936168
# Average loss at step 6000: 3.710442
# Average loss at step 8000: 3.524009
# Average loss at step 10000: 3.479033
# Nearest to were: are, was, had, universiteit, shaping, is, interrogation, apocalyptic,
# Nearest to b: d, chronicler, cypriots, applicative, alex, sparkle, proconsular, dictum,
# Nearest to use: lithographs, hissing, rgensen, ine, numerology, aranese, devotions, nephites,
# Nearest to states: shir, kingdom, targaryen, support, knoxville, hanse, curator, rerio,
# Nearest to american: brut, lately, pitches, mines, scorned, beers, british, sandworm,
# Nearest to six: eight, five, four, nine, seven, three, zero, two,
# Nearest to with: alliances, onward, temporal, misled, lyotropic, of, shivaji, ghq,
# Nearest to four: six, three, eight, five, seven, two, zero, nine,
# Nearest to on: physiol, in, preconditions, internationals, through, about, formosa, aai,
# Nearest to they: he, we, there, adverb, waff, who, humiliating, frauds,
# Nearest to used: known, found, called, available, patinkin, considered, horkheimer, arguable,
# Nearest to so: baikonur, unintentionally, limits, sketch, expressions, mcduck, mouthpiece, rgen,
# Nearest to but: darts, however, pregnancies, meleon, fantagraphics, corals, daly, enroll,
# Nearest to or: and, than, framed, katana, conflated, homeschool, oligocene, futurology,
# Nearest to after: before, for, jaws, disadvantageous, during, barefoot, vestry, shannon,
# Nearest to are: were, is, hancock, was, have, syllogisms, hedgehog, giuliani,
# Average loss at step 12000: 3.489808
# Average loss at step 14000: 3.436181
# Average loss at step 16000: 3.427949
# Average loss at step 18000: 3.403490
# Average loss at step 20000: 3.217461
# Nearest to were: are, was, is, include, have, being, acetic, became,
# Nearest to b: d, dictum, eum, mugwort, dhimmis, cyclones, vasari, proconsular,
# Nearest to use: quota, aranese, utter, keep, support, absinthium, technetium, hypomanic,
# Nearest to states: kingdom, nations, era, rerio, balanced, bridges, topology, biases,
# Nearest to american: videogame, british, castles, atzeret, snark, burner, intercollegiate, transnistrian,
# Nearest to six: seven, five, four, eight, three, nine, zero, two,
# Nearest to with: heathland, including, like, temporal, hal, by, after, misled,
# Nearest to four: six, seven, five, eight, three, zero, nine, two,
# Nearest to on: upon, aai, preconditions, within, prank, through, in, luton,
# Nearest to they: we, there, you, these, he, waff, microstates, warmblood,
# Nearest to used: found, available, known, considered, common, referred, written, seen,
# Nearest to so: unintentionally, baikonur, rushing, topped, ansar, tiny, homology, reyes,
# Nearest to but: and, however, although, while, darts, inhibitory, since, than,
# Nearest to or: and, diss, deteriorating, than, furioso, framed, partitions, butterfield,
# Nearest to after: before, during, for, when, despite, with, combinatory, haphazard,
# Nearest to are: were, is, include, was, being, have, apparitions, hew,
# Average loss at step 22000: 3.359798
# Average loss at step 24000: 3.293423
# Average loss at step 26000: 3.249408
# Average loss at step 28000: 3.292128
# Average loss at step 30000: 3.231495
# Nearest to were: are, was, include, have, had, hedgehog, is, javelin,
# Nearest to b: legate, gopher, alliteration, abauzit, yokoi, d, memoir, empty,
# Nearest to use: support, catalogs, quota, hypomanic, punt, technetium, aranese, name,
# Nearest to states: kingdom, nations, topology, shir, airlines, introns, rerio, flashes,
# Nearest to american: null, intercollegiate, foreskin, america, chemists, atzeret, canadian, wingers,
# Nearest to six: five, seven, eight, four, nine, zero, three, two,
# Nearest to with: between, and, outcasts, including, heathland, evas, bunker, trigonometry,
# Nearest to four: three, five, six, seven, eight, zero, nine, two,
# Nearest to on: upon, in, through, about, within, memel, minimising, physiol,
# Nearest to they: we, there, you, he, waff, frauds, she, nod,
# Nearest to used: referred, considered, known, seen, called, written, held, available,
# Nearest to so: duval, topped, puts, ansar, fact, sometimes, homology, too,
# Nearest to but: however, although, than, and, darts, see, though, daly,
# Nearest to or: and, than, billed, coy, mcqueen, brady, diss, ionia,
# Nearest to after: before, during, despite, for, through, following, without, since,
# Nearest to are: were, is, include, was, casablanca, hwv, do, have,
# Average loss at step 32000: 3.012607
# Average loss at step 34000: 3.196798
# Average loss at step 36000: 3.188833
# Average loss at step 38000: 3.157192
# Average loss at step 40000: 3.153776
# Nearest to were: are, was, include, is, had, being, rutgers, have,
# Nearest to b: d, f, c, regiments, four, gopher, yokoi, whirlwind,
# Nearest to use: quota, description, hypomanic, support, form, amount, application, abdication,
# Nearest to states: kingdom, nations, shir, luncheon, denied, topology, torgau, bridges,
# Nearest to american: america, european, skunk, canadian, australian, atzeret, scheer, deputy,
# Nearest to six: seven, five, eight, four, zero, three, nine, two,
# Nearest to with: between, pannonian, forgetfulness, delved, headway, appreciating, kofi, heathland,
# Nearest to four: five, seven, six, eight, three, zero, nine, two,
# Nearest to on: upon, through, about, at, in, quarrels, within, over,
# Nearest to they: we, you, he, she, frauds, mehrgarh, there, these,
# Nearest to used: written, referred, seen, available, considered, described, found, designed,
# Nearest to so: fact, too, hekate, ababa, sometimes, topped, believe, felt,
# Nearest to but: however, although, and, while, dou, than, though, odense,
# Nearest to or: and, than, contractions, kabuki, while, basutoland, but, hadadezer,
# Nearest to after: before, during, despite, while, since, following, disadvantageous, afterwards,
# Nearest to are: were, include, is, was, being, javelin, have, do,
# Average loss at step 42000: 3.212318
# Average loss at step 44000: 3.146270
# Average loss at step 46000: 3.138439
# Average loss at step 48000: 3.050326
# Average loss at step 50000: 3.055397
# Nearest to were: are, was, being, is, had, include, have, be,
# Nearest to b: d, nipple, invalidate, harrington, proconsular, backdrop, djibouti, impeded,
# Nearest to use: hypomanic, usage, zx, usemodwiki, tact, addition, era, treatment,
# Nearest to states: kingdom, nations, luncheon, shir, emirates, denied, uniting, lasso,
# Nearest to american: british, australian, kaj, atzeret, ind, america, easter, tendencies,
# Nearest to six: five, seven, eight, four, three, nine, zero, two,
# Nearest to with: between, require, dow, francia, misled, temporal, amuse, paradoxically,
# Nearest to four: five, three, six, seven, eight, two, zero, nine,
# Nearest to on: upon, through, immaterial, about, memel, over, within, modality,
# Nearest to they: you, we, he, she, there, himmler, mehrgarh, frauds,
# Nearest to used: considered, found, seen, written, referred, known, held, available,
# Nearest to so: too, sometimes, reyes, amino, believe, thus, demoted, dogg,
# Nearest to but: although, though, and, darts, because, however, resented, bless,
# Nearest to or: and, than, ionia, montenegrins, kabuki, quadrant, like, electrochemistry,
# Nearest to after: before, during, afterwards, following, without, despite, limbaugh, later,
# Nearest to are: were, is, was, include, being, remain, have, aerosmith,
# Average loss at step 52000: 3.097188
# Average loss at step 54000: 3.088464
# Average loss at step 56000: 2.917534
# Average loss at step 58000: 3.023222
# Average loss at step 60000: 3.044401
# Nearest to were: are, was, include, is, being, had, remain, pows,
# Nearest to b: d, x, c, siam, positioned, hendrik, backdrop, zur,
# Nearest to use: form, refer, quota, hypomanic, usage, proportion, malone, lead,
# Nearest to states: kingdom, nations, luncheon, claims, emirates, airlines, lasso, denied,
# Nearest to american: australian, canadian, america, atzeret, microcomputer, british, scheer, feistel,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to with: between, including, makes, among, dow, homeostatic, heathland, safeguarding,
# Nearest to four: three, seven, six, five, eight, zero, two, nine,
# Nearest to on: upon, about, through, immaterial, at, resemblances, in, under,
# Nearest to they: we, you, he, she, players, there, mutagens, who,
# Nearest to used: referred, considered, called, seen, known, employed, described, available,
# Nearest to so: too, sometimes, amino, hekate, believe, maynooth, topped, marais,
# Nearest to but: although, however, and, than, though, while, discontinuities, dramatically,
# Nearest to or: and, than, charon, assistive, deteriorating, while, including, unlike,
# Nearest to after: before, during, following, despite, afterwards, upon, thereafter, since,
# Nearest to are: were, is, include, was, have, including, remain, exist,
# Average loss at step 62000: 3.022873
# Average loss at step 64000: 2.921916
# Average loss at step 66000: 2.934263
# Average loss at step 68000: 2.970984
# Average loss at step 70000: 3.006830
# Nearest to were: are, was, is, had, include, being, gneiss, been,
# Nearest to b: d, nipple, sulfuric, intentionality, yokoi, reluctantly, harrington, proconsular,
# Nearest to use: hypomanic, guinean, proportion, quota, tact, usage, speak, version,
# Nearest to states: kingdom, nations, luncheon, emirates, uniting, lasso, claims, proportions,
# Nearest to american: australian, canadian, british, english, atzeret, nicolai, america, darmstadt,
# Nearest to six: seven, five, three, eight, four, two, zero, nine,
# Nearest to with: between, among, dow, onward, berenguer, when, diputados, tidal,
# Nearest to four: five, six, three, seven, two, policymakers, zero, eight,
# Nearest to on: upon, through, in, about, memel, under, beside, towards,
# Nearest to they: we, you, he, there, hypnotized, ssy, humans, she,
# Nearest to used: found, referred, seen, employed, described, considered, written, available,
# Nearest to so: believe, too, heavenly, marais, topped, sometimes, amino, fact,
# Nearest to but: although, though, and, than, however, which, while, because,
# Nearest to or: and, than, while, though, but, rockville, assistive, snow,
# Nearest to after: before, during, following, despite, when, since, for, within,
# Nearest to are: were, is, include, was, exist, have, contain, neva,
# Average loss at step 72000: 2.945706
# Average loss at step 74000: 2.877653
# Average loss at step 76000: 2.999133
# Average loss at step 78000: 3.004350
# Average loss at step 80000: 2.838386
# Nearest to were: are, was, is, include, various, remain, newly, bornu,
# Nearest to b: d, mathbf, nipple, f, transcendentalism, bailey, k, faceted,
# Nearest to use: usage, form, proportion, addition, application, hypomanic, contribution, support,
# Nearest to states: nations, kingdom, luncheon, claims, airlines, branches, provinces, emirates,
# Nearest to american: america, australian, canadian, african, atzeret, italian, atlantic, british,
# Nearest to six: seven, four, five, eight, three, zero, nine, two,
# Nearest to with: between, among, anubis, heathland, via, against, safeguarding, dow,
# Nearest to four: six, seven, five, three, eight, zero, two, nine,
# Nearest to on: upon, in, through, modality, immaterial, toward, vitamins, dojo,
# Nearest to they: we, you, she, he, there, humans, i, mutagens,
# Nearest to used: referred, available, seen, found, described, applied, intended, considered,
# Nearest to so: too, sometimes, theodora, khanna, fact, what, hekate, increasingly,
# Nearest to but: though, however, although, and, see, because, fairness, or,
# Nearest to or: and, though, ursidae, etc, superhuman, than, marinetti, milgrom,
# Nearest to after: before, following, despite, during, upon, thereafter, without, mckean,
# Nearest to are: were, is, include, was, contain, have, exist, remain,
# Average loss at step 82000: 2.934459
# Average loss at step 84000: 2.896336
# Average loss at step 86000: 2.914705
# Average loss at step 88000: 2.945397
# Average loss at step 90000: 2.834767
# Nearest to were: are, was, is, newly, include, various, have, timely,
# Nearest to b: d, f, c, cip, reasonable, r, presiding, omega,
# Nearest to use: amount, guinean, think, because, abdication, support, introduction, detect,
# Nearest to states: kingdom, nations, airlines, emirates, claims, luncheon, shir, branches,
# Nearest to american: america, australian, canadian, amateur, intercollegiate, monophysites, individual, british,
# Nearest to six: seven, eight, four, three, five, nine, zero, two,
# Nearest to with: between, via, coloureds, heathland, among, safeguarding, disowned, ghq,
# Nearest to four: six, five, three, seven, eight, zero, two, nine,
# Nearest to on: upon, through, in, behind, physiol, formosa, memel, resemblances,
# Nearest to they: we, you, he, there, she, audubon, i, it,
# Nearest to used: referred, available, designed, intended, employed, found, applied, performed,
# Nearest to so: sometimes, too, fact, khanna, believe, theodora, say, foretold,
# Nearest to but: though, however, although, kofi, and, involve, phytoplankton, see,
# Nearest to or: and, than, misidentification, unmanned, ayla, charon, kabuki, lubavitch,
# Nearest to after: before, during, despite, following, when, upon, without, since,
# Nearest to are: were, is, include, was, contain, have, exist, allow,
# Average loss at step 92000: 2.888095
# Average loss at step 94000: 2.881682
# Average loss at step 96000: 2.716344
# Average loss at step 98000: 2.456738
# Average loss at step 100000: 2.709132
# Nearest to were: are, was, have, had, include, remain, is, being,
# Nearest to b: d, yorkshire, deaths, proconsular, invalidate, tagus, comedian, quadrivium,
# Nearest to use: support, form, version, contribution, proportion, development, amount, usage,
# Nearest to states: kingdom, nations, luncheon, airlines, emirates, unrequited, zubaydah, artists,
# Nearest to american: australian, canadian, english, irish, british, german, russian, scottish,
# Nearest to six: seven, five, four, eight, three, nine, zero, two,
# Nearest to with: between, among, via, homeostatic, using, heathland, safeguarding, delved,
# Nearest to four: six, three, five, seven, eight, two, zero, nine,
# Nearest to on: upon, through, concerning, physiol, in, ep, resemblances, bench,
# Nearest to they: we, you, she, he, there, i, selznick, carcinogenic,
# Nearest to used: referred, designed, applied, seen, introduced, considered, described, intended,
# Nearest to so: sometimes, too, theodora, khanna, felt, unintentionally, fact, believe,
# Nearest to but: and, however, than, although, though, or, while, involve,
# Nearest to or: and, than, but, while, agnostics, though, deteriorating, gilligan,
# Nearest to after: before, following, despite, upon, thereafter, ago, later, for,
# Nearest to are: were, is, have, contain, include, was, remain, exist,
# Ended

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ### Conclusion
#
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works!
# At the first sight, they look similar. The CBOW seems more compact.
